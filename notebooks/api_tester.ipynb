# %%
import pandas as pd
import requests
import json

# %%
df_test = pd.read_csv('../data/test.csv')
df_test
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       381110    Male   25                1         11.0                   1
# 1       381111    Male   40                1         28.0                   0
# 2       381112    Male   47                1         28.0                   0
# 3       381113    Male   24                1         27.0                   1
# 4       381114    Male   27                1         28.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 127032  508142  Female   26                1         37.0                   1
# 127033  508143  Female   38                1         28.0                   0
# 127034  508144    Male   21                1         46.0                   1
# 127035  508145    Male   71                1         28.0                   1
# 127036  508146    Male   41                1         29.0                   1
#
# ...

# %%
teste = df_test.sample(frac = .001)
teste.shape
# Out:
# (127, 11)

# %%
data = json.dumps(teste.to_dict(orient = 'records'))

# %%
url = 'http://127.0.0.1:5000/healthinsurance/predict'
header = {'Content-type':'application/json'}

# %%
r = requests.post(url, data = data,headers=header)
print(r.status_code)
# Out:
# 200

# %%
d1 = pd.DataFrame(r.json(), columns = r.json()[0].keys())
d1.sort_values(by=['score'], ascending = False).head()
# Out:
#        id    gender       age  driving_license  region_code  \
# 0  438065  0.138568  0.464286                1      0.18812
# 1  384851  0.138568  0.357143                1      0.18812
# 2  424458  0.138568  0.535714                1      0.18812
# 3  472594  0.138568  0.375000                1      0.18812
# 4  485604  0.104654  0.571429                1      0.18812
#
#    previously_insured        vehicle_age  vehicle_damage  annual_premium  \
# 0                   0  between_1_2_years               1        0.558206
# 1                   0  between_1_2_years               1        0.307741
# 2                   0  between_1_2_years               1        0.991497
# 3                   0  between_1_2_years               1       -0.591178
# 4                   0  between_1_2_years               1        0.418386
#
#    policy_sales_channel   vintage     score
# 0                  13.0  0.500000  0.325103
# 1                 156.0  0.248252  0.324299
# ...
